# %% [markdown]
# # **Built-in Tool : DuckDuckGo Search**

# %%
# !pip install duckduckgo-search langchain-community

# %%
# !pip install -U ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 68.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.4.0
#     Uninstalling lxml-5.4.0:
#       Successfully uninstalled lxml-5.4.0
# ...

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()

search.invoke("Which Team Won the Asia Cup 2025 in Cricket")
# Out:
# "The 2025 Men's Asia Cup was the 17th edition of the Asia Cup cricket tournament. It took place in the United Arab Emirates from 9 to 28 September 2025 . The matches were played in the Twenty20 International format. India was the defending champio... The Indian cricket team cruised to a six-wicket victory against Pakistan in their first Super 4 game of Asia Cup 2025 as Abhishek Sharma lit up the Dubai Cricket Stadium with a match- winning innings on Sunday. Asia Cup Points Table 2025 - Check updated team rankings, net run rate, wins , standings and real-time match results, only on CricTracker.The top two teams in the Super Four will meet in the final, which scheduled for September 28, 2025 , at the Dubai International Cricket Stadium. Asia Cup 2025 Schedule, Match Timings, Venue Details, Upcoming Cricket Matches and Recent Results on Cricbuzz.com.Dubai International Cricket Stadium, Dubai. Pakistan won by 93 runs. Get Asia Cup 2025 , fixtures, scorecard updates, and results on ESPNcr
# ...

# %%
print(search.name)
print(search.description)
print(search.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# # **Built-in Tool : Wikipedia**

# %%
# !pip install --upgrade --quiet  wikipedia
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# %%
wikipedia = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())

# %%
wikipedia.run("Future of Agentic AI")
# Out:
# 'Page: Agentic AI\nSummary: Agentic AI is a class of artificial intelligence that focuses on autonomous systems that can make decisions and perform tasks with limited or no human intervention. The independent systems automatically respond to conditions to produce process results. The field is closely linked to agentic automation, also known as agent-based process management systems, when applied to process automation. Applications include software development, customer support, cybersecurity and business intelligence.\n\nPage: Intelligent agent\nSummary: In artificial intelligence, an intelligent agent is an entity that perceives its environment, takes actions autonomously to achieve goals, and may improve its performance through machine learning or by acquiring knowledge. AI textbooks define artificial intelligence as the "study and design of intelligent agents," emphasizing that goal-directed behavior is central to intelligence.\nA specialized subset of intelligent agents, agentic 
# ...

# %%
print(wikipedia.name)
print(wikipedia.description)
print(wikipedia.args)
# Out:
# wikipedia
# A wrapper around Wikipedia. Useful for when you need to answer general questions about people, places, companies, facts, historical events, or other subjects. Input should be a search query.
# {'query': {'description': 'query to look up on wikipedia', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# # **Built-in Tool : Shell(Bash) Tool**

# %%
# !pip install langchain-experimental
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 6.9 MB/s eta 0:00:00
# ...

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.run("ls")

result2 = shell_tool.run("whoami")

print(results)
print("===================")
print(result2)
# Out:
# Executing command:
#  ls
# Executing command:
#  whoami
# sample_data
#
# ...
# root
# /usr/local/lib/python3.12/dist-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %%
print(shell_tool.name)
print(shell_tool.description)
print(shell_tool.args)
# Out:
# terminal
# Run shell commands on this Linux machine.
# {'commands': {'anyOf': [{'type': 'string'}, {'items': {'type': 'string'}, 'type': 'array'}], 'description': 'List of shell commands to run. Deserialized using json.loads', 'title': 'Commands'}}
